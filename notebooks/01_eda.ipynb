# %% [markdown]
# # Churn Modelling — Exploratory Data Analysis
#
# Quick exploration of the dataset before training. Not part of the pipeline.

# %%
from mlops_churn import data
df = data.load_raw()
df.head()

# %%
df.describe()

# %%
df['Exited'].value_counts(normalize=True)
